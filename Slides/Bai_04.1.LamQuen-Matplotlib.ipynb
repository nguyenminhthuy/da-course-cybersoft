# %%
# %%html
# <style type='text/css'>
# .CodeMirror{
#     font-size: 18px;
# }
#
# div.output_area pre {
#     font-size: 16px;
# }
# </style>
# Out:
# <style type='text/css'>
# .CodeMirror{
#     font-size: 18px;
# }
#
# div.output_area pre {
#     font-size: 16px;
# }
# </style>

# %% [markdown]
# # Phần 1. Giới thiệu

# %%
import matplotlib
import matplotlib.pyplot as plt

print(matplotlib.__version__)
# print(matplotlib)
# print(plt)
# Out:
# 3.4.3

# %% [markdown]
# ## 1.1) Ví dụ

# %%
# Cách sử dụng đơn giản

x = [1,2,3]
y = [6,4,5]

plt.plot(x,y)
plt.show()

# %%
# Thêm vào một số thông tin và trang trí

plt.plot([1,2,3], [6,4,5], color="red", marker="o")
plt.title("Demo Vẽ Hình với Matplot.Pyplot", fontsize=16, fontweight="bold", color="blue")
plt.xlabel("Giá trị của x", fontsize=14, color="green")
plt.ylabel("Giá trị của y", fontsize=14, color="red")
plt.xticks(x)
plt.yticks(y)
plt.show()

# %%
# Sử dụng các biểu đồ con: Subplots
plt.subplot(1,2,1)
plt.plot([1,2,3], [6,4,5], color="red", marker="o")

plt.subplot(1,2,2)
plt.plot([1,2,3], [3,5,0], color="green", marker="^")
plt.show()

# %%
# Ví dụ về vẽ đường thẳng
A = [3,4]
B = [1,6]

plt.plot([A[0], B[0]], [A[1], B[1]], marker="o")
plt.xticks([0,1,2,3,4,5])
plt.yticks([0,1,2,3,4,5,6,7])

# In nhãn "A" và "B" lên biểu đồ
plt.text(A[0], A[1]+0.1, "A", size=16)
plt.text(B[0]-0.2, B[1]-0.2, "B", size=16)

plt.xlim([0, 5])
plt.ylim([0,7])
plt.grid()

plt.show()

# %% [markdown]
# ## 1.3) Cấu trúc của biểu đồ trong Matplotlib

# %% [markdown]
# **Khởi tạo các subplot**

# %%
# Cách 1: sử dụng hàm plt.subplot()

axes_1 = plt.subplot(1, 2, 1) # dòng, cột, vị trí bên nào

axes_2 = plt.subplot(1, 2, 2) # dòng, cột, vị trí bên nào

axes_1.plot(x,y)

plt.show()

# %%
# Cách 2: sử dụng fig.add_subplot()
fig = plt.figure()

ax1 = fig.add_subplot(2, 1, 1)
ax2 = fig.add_subplot(3, 2, 5)

plt.show()

# %% [markdown]
# **Vẽ vào các subplot**

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2, 2, 1)
ax1.plot(x,y)

ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)

ax2.plot([6,4,5], [1,2,3])
ax3.plot([1,2,3], [5,4,8])

# Giả sử muốn vẽ thêm và ax1
ax1.plot([1.5, 2.5], [4.5, 5.5]) # truyền gt x trước, y sau


plt.show()

# %% [markdown]
# **Đồng nhất scale của các trục**

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2, 2, 1)
plt.plot([1,2,3], [6,4,5], color="red", marker="o")

ax2 = fig.add_subplot(2, 2, 2, sharey = ax1) 
# sharey: gt trục y giống nhau
# sharex: gt trục x giống nhau

plt.plot([1,2,3], [6,24,15], color="green", marker="o")

ax3 = fig.add_subplot(2, 2, 3, sharex = ax1)
plt.plot([10,15,30], [6,14,5], color="blue", marker="o")
# ax4 = fig.add_subplot(2, 2, 4)
plt.show()

# %% [markdown]
# **Sắp xếp các subplot có kích thước khác nhau**

# %%
fig = plt.figure()
ax1 = fig.add_subplot(4, 2, 1)
ax2 = fig.add_subplot(2, 1, 2)
# ax3 = fig.add_subplot(4, 2, 5)
ax4 = fig.add_subplot(4, 2, 8)

plt.show()

# %% [markdown]
# **Tạo subplot nằm ngang/dọc**

# %%
# Tạo subplot nằm ngang
fig = plt.figure()

ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)

ax3 = fig.add_subplot(2, 1, 2)

plt.show()

# %%
# Tạo subplot nằm dọc
fig = plt.figure()

ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 3)

# fig.add_subplot(2, 2, 2)
# fig.add_subplot(2, 2, 4)

ax3 = fig.add_subplot(1, 2, 2)

plt.show()

# %% [markdown]
# **Tạo ra nhiều Figures trong một hình biểu diễn**

# %%
# Tạo ra figure thứ nhất
fig1 = plt.figure()
ax11 = fig1.add_subplot(2, 2, 1)
ax12 = fig1.add_subplot(2, 2, 2)
ax13 = fig1.add_subplot(2, 1, 2)
fig1.suptitle("Biểu đồ 1")

# Tạo ra figure thứ hai
fig2 = plt.figure()
ax21 = fig2.add_subplot(1, 2, 1)
ax22 = fig2.add_subplot(2, 2, 2)
ax23 = fig2.add_subplot(2, 2, 4)
fig2.suptitle("Biểu đồ 2")

plt.show()

# %% [markdown]
# **Dùng phép lặp để truy cập các Axes**

# %%
# Khi tạo subplot, các subplots được lưu vào một list
fig, axes = plt.subplots(3, 2, constrained_layout=True)
print(axes.shape)
axes[1][1].plot(x,y)

for i in range(3):
    for j in range(2):
        print(axes[i][j])
# Out:
# (3, 2)
# AxesSubplot(0.125,0.657941;0.352273x0.222059)
# AxesSubplot(0.547727,0.657941;0.352273x0.222059)
# AxesSubplot(0.125,0.391471;0.352273x0.222059)
# AxesSubplot(0.547727,0.391471;0.352273x0.222059)
# AxesSubplot(0.125,0.125;0.352273x0.222059)
# AxesSubplot(0.547727,0.125;0.352273x0.222059)

# %%
# Khi tạo subplot, các subplots được lưu vào một list
fig,axes = plt.subplots(3, 2, constrained_layout=True)
print(axes.shape)

for i in range(3):
    for j in range(2):
        ax = axes[i][j]
        ax.plot([1,2,3], [6,4,5])

plt.show()
# Out:
# (3, 2)

# %% [markdown]
# # Phần 2. Sử dụng hàm plot()

# %% [markdown]
# **Vẽ một thông số**

# %%
plt.plot([1,2,3], [6,4,5],
         color='b', label="Doanh Thu/Thang",
         marker='X', markersize=12,
         linestyle=':', linewidth=3, alpha=1,
        )

plt.title("Demo Hàm plot()")
plt.xlabel("Giá trị của x")
plt.ylabel("Giá trị của y")

plt.xticks(x)
plt.yticks(y)

plt.show()

# %%
# Nếu không cần đường kẻ
ax1 = plt.subplot(1,2,1)
ax1.plot([1,2,3], [6,4,5], color="red", marker="o", linestyle="dashed")

ax2 = plt.subplot(1,2,2)
ax2.plot([1,2,3], [3,5,0], color="green", marker="^", linestyle="")
plt.show()

# %% [markdown]
# **Vẽ vài thông số**

# %%
plt.plot([1,2,3], [6,4,5], color='blueviolet', marker="v", markersize=12, ls="-.")
plt.plot([1,2,3], [3,6,7], color='red', marker="D", markersize=10, ls="--", lw=3)
plt.show()

# %% [markdown]
# **Kết hợp chỉ định color/marker/linestyle**

# %%
# Kết hợp chỉ định color/marker/linestyle
x1,y1 = [1, 2, 3], [4, 2, 3]
x2,y2 = [4, 5, 6], [7, 2, 3]

plt.plot(x1, y1, 'gD--', lw=3)
plt.plot(x2, y2, 'ro-.')

plt.show()

# %%
plt.plot([1,2,3], [6,4,5], "gv-.", [1,2,3,4,5],[2,1,4,3,7], "bp-", markersize=12)
plt.plot([1,2,3], [3,6,7], color='red', marker="D", markersize=10, ls="--", lw=3)
plt.show()

# %% [markdown]
# **Gán nhãn và sử dụng legend**

# %%
plt.plot([1, 2, 3], [1, 2, 3], 'go-', label='Chi Nhánh 1')
plt.plot([1,2,3], [3,6,7], 'r^-', label='Chi Nhánh 2')

plt.legend()

plt.show()

# %%
# Chỉnh sửa lại legend
fig = plt.figure(figsize=[4,4])

plt.plot([1, 2, 3], [1, 2, 3], 'go-', label='Chi Nhánh 1')
plt.plot([1,2,3], [3,6,7], 'r^-', label='Chi Nhánh 2')

plt.legend(labels=["Branch-1", 'Branch-2'])

plt.show()

# %%
# Chỉnh sửa lại legend
fig = plt.figure(figsize=[4,4])

plt.plot([1, 2, 3], [1, 2, 3], 'go-', label='Chi Nhánh 1')
plt.plot([1,2,3], [3,6,7], 'r^-', label='Chi Nhánh 2')

plt.legend(labels=["Branch-1", 'Branch-2'], loc="lower right")

plt.show()

# %%
# Chỉnh sửa lại legend
fig = plt.figure(figsize=[4,4])

plt.plot([1, 2, 3], [1, 2, 3], 'go-', label='Chi Nhánh 1')
plt.plot([1,2,3], [3,6,7], 'r^-', label='Chi Nhánh 2')

plt.legend(labels=["Branch-1", 'Branch-2'], loc=[1.1, 0.8])

plt.show()

# %%
# Chỉnh sửa lại legend
fig = plt.figure(figsize=[4,4])

plt.plot([1, 2, 3], [1, 2, 3], 'go-', label='Chi Nhánh 1')
plt.plot([1,2,3], [3,6,7], 'r^-', label='Chi Nhánh 2')

plt.legend(labels=["Branch-1", 'Branch-2'], loc=[0.35, 0.3], ncol=1)

plt.show()

# %% [markdown]
# # Phần 3. Các thao tác cơ bản khác

# %% [markdown]
# ## 3.1) Figure size và tight_layout

# %% [markdown]
# **Có thể sử dụng `constrained_layout=True` hoặc `plt.tight_layout`**

# %%
x = [1,2,3]
y = [6,4,5]

# %%
fig = plt.figure(figsize=[8, 5])
ax1 = fig.add_subplot(2, 2, 1)
ax1.plot(x,y, color="b")
ax1.set_ylabel("Doanh thu", size=12, weight="bold", color="blue")
ax1.set_xlabel("Theo Tháng")

ax2 = fig.add_subplot(2, 2, 2)
ax2.set_ylabel("Doanh số", size=12, color="r")
plt.plot(y,x, color="r")
ax2.set_xlabel("Theo Tuần")

ax3 = fig.add_subplot(2, 1, 2)
plt.plot(x,y)
plt.xlabel("Theo Quý")
#plt.axis("off")
ax3.set_xticks([1.2,2.2,3.2])
ax3.set_xticklabels(["Quý 1", "Quý 2", "Quý 3"])

ax2.set_ylim([0,4])

plt.tight_layout() # khoảng cách giữa các biểu đồ
plt.show()

# %%
fig = plt.figure(figsize=(8,6), constrained_layout=True)
ax1 = fig.add_subplot(2, 2, 1)
ax1.plot(x,y, color="b")
ax1.set_ylabel("Doanh thu", size=12, weight="bold", color="blue")
ax1.set_xlabel("Theo Tháng")

ax2 = fig.add_subplot(2, 2, 2)
ax2.set_ylabel("Doanh số", size=12, color="r")
plt.plot(y,x, color="r")
ax2.set_xlabel("Theo Tuần")

ax3 = fig.add_subplot(2, 1, 2)
plt.plot(x,y)
plt.xlabel("Theo Quý")
#plt.axis("off")
ax3.set_xticks([1.2,2.2,3.2])
ax3.set_xticklabels(["Quý 1", "Quý 2", "Quý 3"])

ax2.set_ylim([0,4])

# plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3.2) Các thao tác trên axis

# %% [markdown]
# **Bật/tắt axis**

# %%
# Bật/tắt axis với plt 
plt.plot([1,2,3], [6,4,5], 
         color="red", alpha=0.5,
         marker="^", markersize=14, 
         linestyle="dashed", linewidth=2)
plt.title("Demo Hàm plot()")
# plt.xlabel("Giá trị của x")
plt.ylabel("Giá trị của y")

plt.axis("on")
plt.xticks([])
plt.yticks([])

plt.show()

# %%
# Bật/tắt axis với ax
fig = plt.figure()
ax1 = fig.add_subplot(2, 2, 1)
plt.plot([1,2,3], [6,4,5], color="red", marker="o")

ax2 = fig.add_subplot(2, 2, 2, sharey=ax1)
plt.plot([1,2,3], [16,4,15], color="green", marker="o")
# ax2.set_axis_off()
ax2.set_yticks([])

ax3 = fig.add_subplot(2, 2, 3, sharex=ax1)
plt.plot([10,15,30], [6,4,5], color="blue", marker="o")

plt.show()

# %%
# Bật/tắt axis với ax
fig = plt.figure()
ax1 = fig.add_subplot(2, 2, 1)
plt.plot([1,2,3], [6,4,5], color="red", marker="o")

ax2 = fig.add_subplot(2, 2, 2, sharey=ax1)
plt.plot([1,2,3], [16,4,15], color="green", marker="o")
# ax2.set_yticks([])

# Để giữ lại axis của figure bên trái
ax2.get_yaxis().set_visible(False)

ax3 = fig.add_subplot(2, 2, 3, sharex=ax1)
plt.plot([10,15,30], [6,4,5], color="blue", marker="o")

ax3.get_xaxis().set_visible(False)

plt.show()

# %% [markdown]
# **Thiết lập limits**

# %%
# Thiết lập limits 
plt.plot([1,2,3], [6,4,5], 
         color="red", alpha=0.5,
         marker="^", markersize=14, 
         linestyle="dashed", linewidth=2)
plt.title("Demo Hàm plot()")
plt.xlabel("Giá trị của x")
plt.ylabel("Giá trị của y")

plt.xlim([0, 4])
plt.ylim([2, 7])

plt.show()

# %%
# Thiết lập limits 
plt.plot([1,2,3], [6,4,5], 
         color="red", alpha=0.5,
         marker="^", markersize=14, 
         linestyle="dashed", linewidth=2)
plt.title("Demo Hàm plot()")
plt.xlabel("Giá trị của x")
plt.ylabel("Giá trị của y")

plt.xlim([0, 4])
plt.ylim([2, 7])

plt.xticks([1, 2, 3], ["Tháng 9", "Tháng 10", "Tháng 11"])

ax1 = plt.gca()
ax1.invert_xaxis() # đảo ngược

plt.show()

# %% [markdown]
# ## 3.3) Hiển thị lưới

# %% [markdown]
# **Hiển thị lưới với plt**

# %%
plt.plot([1,2,3], [6,4,5], 
         color="red", alpha=0.5,
         marker="^", markersize=14, 
         linestyle="dashed", linewidth=2)
plt.title("Demo Hàm plot()")
plt.xlabel("Giá trị của x")
plt.ylabel("Giá trị của y")
plt.xlim([0,10])
plt.ylim([0,10])

plt.grid()

plt.show()

# %% [markdown]
# **Hiển thị lưới trên một axes**

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2, 2, 1)
plt.plot([1,2,3], [6,4,5], color="red", marker="o")

ax2 = fig.add_subplot(2, 2, 2, sharey=ax1)
plt.plot([1,2,3], [16,4,15], color="green", marker="o")
ax2.grid(linestyle="--", linewidth=0.5, color='.25')

ax3 = fig.add_subplot(2, 2, 3, sharex=ax1)
plt.plot([10,15,30], [6,4,5], color="blue", marker="o")

plt.show()

# %% [markdown]
# ## 3.4) Lưu file ảnh

# %% [markdown]
# (Có thể lưu file `.png`, `.jpg`, `.svg`, `.pdf`, ...)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2, 2, 1)
plt.plot([1,2,3], [6,4,5], color="red", marker="o")

ax2 = fig.add_subplot(2, 2, 2, sharey=ax1)
plt.plot([1,2,3], [16,4,15], color="green", marker="o")
ax2.grid(linestyle="--", linewidth=0.5, color='.25')

ax3 = fig.add_subplot(2, 2, 3, sharex=ax1)
plt.plot([10,15,30], [6,4,5], color="blue", marker="o")

plt.savefig("example.pdf", facecolor="w", transparent=True)

plt.show()

# %% [markdown]
# # 4. Thử áp dụng để vẽ CandleChart (Biểu Đồ Nến)

# %%
def Ve_Nen(x, dong_cua, mo_cua, cao, thap):
    plt.plot([x, x], [thap, cao], color='k')
    plt.plot([x, x], [dong_cua, mo_cua], color="red", lw=8)

Ve_Nen(1, 30, 25, 33, 21)
Ve_Nen(2, 33, 35, 37, 28)
    
plt.show()
